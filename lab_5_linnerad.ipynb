# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_linnerud
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor

# %%
data = load_linnerud()
X, y = data.data, data.target
feature_names = data.feature_names
target_names = data.target_names

# Display dataset information
print("Feature Names:", feature_names)
print("Target Names:", target_names)
print("Data Shape:", X.shape)
print("Target Shape:", y.shape)

# Plot the data
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
    axs[i].scatter(X[:, i], y[:, i])
    axs[i].set_xlabel(feature_names[i])
    axs[i].set_ylabel(target_names[i])
    axs[i].set_title(f"{feature_names[i]} vs. {target_names[i]}")

plt.tight_layout()
plt.show()
# Out:
# Feature Names: ['Chins', 'Situps', 'Jumps']
# Target Names: ['Weight', 'Waist', 'Pulse']
# Data Shape: (20, 3)
# Target Shape: (20, 3)

# %%
# Load the dataset
X, y = load_linnerud(return_X_y=True)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create and evaluate models
models = {
    "KNeighborsRegressor": KNeighborsRegressor(),
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso()
}

model_scores = {}

for model_name, model in models.items():
    model.fit(X_scaled, y)
    score = model.score(X_scaled, y)
    model_scores[model_name] = score

# Plot the model scores
plt.figure(figsize=(10, 6))
plt.bar(model_scores.keys(), model_scores.values(), color='skyblue')
plt.title('Model Performance')
plt.ylabel('R-squared Score')
plt.xticks(rotation=15)
plt.ylim(0, 1.0)

for model_name, score in model_scores.items():
    plt.text(model_name, score, f'{score:.2f}', ha='center', va='bottom')
plt.show()

# %% [markdown]
#  набор данных Linnerud для создания и оценки нескольких моделей регрессии.
#  Используется набор данных Linnerud, включающий физиологические и тренировочные данные.
# Признаки хранятся в переменной X, а целевые значения в yод создает субграфик с тремя точечными диаграммами, каждая из которых отображает зависимость признака от соответствующей целевой переменной. Используются четыре модели регрессии: KNeighborsRegressor, LinearRegression, Ridge и Lasso.
# Признаки стандартизируются с использованием StandardScaler перед обучением моделей.
# В цикле каждая модель обучается на данных, и затем вычисляется коэффициент детерминации (R-squared) для оценки производительности моделКоэффициенты детерминации предоставляют меру того, насколько каждая модель хорошо описывает вариацию данных.
# Выбор лучшей модели зависит от конкретных характеристик набора данных.
# Визуализация данных и метрики производительности моделей важны для понимания взаимосвязей и выбора подходящих моделейи..
